# %% [markdown]
# <a href="https://colab.research.google.com/github/traderjohnd/foundation-model-from-scratch/blob/main/notebooks/01_data_and_tokenizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building a Foundation Model from Scratch
# ## Notebook 01 — Data Preparation & Corpus Audit
#
# This notebook establishes the controlled data and tokenization pipeline shared by all three decoder-only Transformer models. The purpose is not merely to download text; it is to create a reproducible experimental foundation so that later differences can be attributed primarily to **model capacity**.
#
# ### Locked project decisions used here
#
# - Source corpus: **WikiText-103**
# - Split policy: official `train`, `validation`, and `test` splits
# - Training budget: exactly **20,000,000 tokenizer-produced tokens** from `train` only
# - Tokenizer: **byte-level BPE**, trained from scratch
# - Vocabulary size: **16,384**
# - Reproducibility seed: **42**
# - The test split remains unused until final evaluation
#
# Canonical references: [`PROJECT_CONTEXT.md`](https://github.com/traderjohnd/foundation-model-from-scratch/blob/main/docs/PROJECT_CONTEXT.md) and [`DECISION_REGISTER.md`](https://github.com/traderjohnd/foundation-model-from-scratch/blob/main/docs/DECISION_REGISTER.md).

# %% [markdown]
# ## 1. Scope of this first implementation chunk
#
# This chunk does four things:
#
# 1. establishes the execution environment;
# 2. applies the project's reproducibility seed;
# 3. loads the raw WikiText-103 dataset; and
# 4. verifies the official splits, schema, and expected row counts.
#
# It deliberately does **not** inspect test examples, preprocess text, train the tokenizer, or construct the 20M-token corpus. Those are later reviewable chunks.

# %% [markdown]
# ## 2. Environment setup
#
# Google Colab usually includes many scientific Python packages, but package versions change over time. We install the two project-specific Hugging Face libraries and then record the actual versions used. Recording versions is more useful for reproducibility than silently assuming a Colab image never changes.

# %%
# %pip install -q datasets tokenizers

# %%
import platform
import random

import datasets
import numpy as np
import pandas as pd
import tokenizers
from datasets import load_dataset
from huggingface_hub import HfApi

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

DATASET_ID = "Salesforce/wikitext"
DATASET_CONFIG = "wikitext-103-raw-v1"
DATASET_REVISION = "b08601e04326c79dfdd32d625aee71d232d685c3"
EXPECTED_SPLITS = ("train", "validation", "test")
EXPECTED_ROWS = {
    "train": 1_801_350,
    "validation": 3_760,
    "test": 4_358,
}
EXPECTED_ARTICLE_COUNTS = {"train": 28_472, "validation": 60}
REFERENCE_FINGERPRINTS = {
    "train": "7dabb830ac9ebb0d",
    "validation": "ea37ea707fafbf9f",
    "test": "c30409b5a24d230f",
}

current_hub_revision = HfApi().dataset_info(DATASET_ID).sha

environment = {
    "python": platform.python_version(),
    "datasets": datasets.__version__,
    "tokenizers": tokenizers.__version__,
    "numpy": np.__version__,
    "pandas": pd.__version__,
    "seed": SEED,
    "pinned_dataset_revision": DATASET_REVISION,
    "current_hub_revision": current_hub_revision,
    "hub_head_matches_pin": current_hub_revision == DATASET_REVISION,
}
pd.Series(environment, name="value").to_frame()
# Out:
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
#                                                             value
# python                                                    3.13.15
# datasets                                                    4.0.0
# tokenizers                                                 0.23.1
# numpy                                                       2.1.3
# pandas                                                      2.2.3
# seed                                                           42
# pinned_dataset_revision  b08601e04326c79dfdd32d625aee71d232d685c3
# current_hub_revision     b08601e04326c79dfdd32d625aee71d232d685c3
# hub_head_matches_pin                                         True

# %% [markdown]
# ## 3. Load WikiText-103
#
# We use the **raw** WikiText-103 configuration, pinned to the exact Hugging Face Hub commit against which the row, article, and fingerprint audits were verified. The live Hub head is recorded for visibility but does not control loading. This prevents a future upstream change from silently changing the corpus. Loading makes all official splits available, but this notebook will not examine test examples.

# %%
raw_dataset = load_dataset(
    DATASET_ID, DATASET_CONFIG, revision=DATASET_REVISION
)
raw_dataset
# Out:
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# wikitext-103-raw-v1/test-00000-of-00001.(…): reconstructing file:   0%|          |  0.00B /  733kB
# wikitext-103-raw-v1/test-00000-of-00001.(…): downloading bytes:           |  0.00B
# wikitext-103-raw-v1/train-00000-of-00002(…): reconstructing file:   0%|          |  0.00B /  157MB
# wikitext-103-raw-v1/train-00000-of-00002(…): downloading bytes:           |  0.00B
# wikitext-103-raw-v1/train-00001-of-00002(…): reconstructing file:   0%|          |  0.00B /  157MB
# wikitext-103-raw-v1/train-00001-of-00002(…): downloading bytes:           |  0.00B
# wikitext-103-raw-v1/validation-00000-of-(…): reconstructing file:   0%|          |  0.00B /  657kB
# wikitext-103-raw-v1/validation-00000-of-(…): downloading bytes:           |  0.00B
# Generating test split:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/1801350 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['text'],
#         num_rows: 4358
#     })
#     train: Dataset({
#         features: ['text'],
#         num_rows: 1801350
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 3760
#     })
# })

# %% [markdown]
# ## 4. Verify the official split contract
#
# This audit checks structure without reading test text. The row counts are not token counts: each dataset row is a text record, while our later 20M-token budget will be measured only after training the project tokenizer. The pinned Hub revision is the upstream provenance anchor. The private `_fingerprint` is retained only as a guarded, best-effort local sanity check; it may vary with tooling or disappear in a future `datasets` release.

# %%
actual_splits = set(raw_dataset.keys())
assert actual_splits == set(EXPECTED_SPLITS), (
    f"Unexpected split set: {sorted(actual_splits)}"
)

audit_rows = []
for split_name in EXPECTED_SPLITS:
    split = raw_dataset[split_name]
    has_text_column = split.column_names == ["text"]
    row_count = len(split)
    observed_fingerprint = getattr(split, "_fingerprint", None)
    audit_rows.append(
        {
            "split": split_name,
            "rows": row_count,
            "expected_rows": EXPECTED_ROWS[split_name],
            "row_count_matches": row_count == EXPECTED_ROWS[split_name],
            "columns": split.column_names,
            "text_schema_ok": has_text_column,
            "fingerprint": observed_fingerprint,
            "reference_fingerprint": REFERENCE_FINGERPRINTS[split_name],
            "fingerprint_matches_reference": (
                observed_fingerprint == REFERENCE_FINGERPRINTS[split_name]
            ),
        }
    )

split_audit = pd.DataFrame(audit_rows).set_index("split")
assert split_audit["row_count_matches"].all(), "Dataset row counts changed."
assert split_audit["text_schema_ok"].all(), "Expected one text column per split."
split_audit
# Out:
#                rows  expected_rows  row_count_matches columns  text_schema_ok  \
# split
# train       1801350        1801350               True  [text]            True
# validation     3760           3760               True  [text]            True
# test           4358           4358               True  [text]            True
#
#                  fingerprint reference_fingerprint  \
# split
# train       7dabb830ac9ebb0d      7dabb830ac9ebb0d
# validation  ea37ea707fafbf9f      ea37ea707fafbf9f
# test        c30409b5a24d230f      c30409b5a24d230f
#
#             fingerprint_matches_reference
# split
# train                                True
# validation                           True
# test                                 True

# %% [markdown]
# ### Checkpoint after Chunk 1
#
# At this point we should be able to confirm:
#
# - the supported dataset identifier resolves;
# - the raw WikiText-103 configuration provides the expected official splits;
# - each split contains a single `text` field;
# - the observed row counts match the dataset record; and
# - no test example has been inspected or used for a decision.
#
# **Chunk 1 is complete.** Chunk 2 below inspects training and validation text without touching test examples.

# %% [markdown]
# # Chunk 2 — Raw-text audit and preprocessing policy
#
# WikiText's `raw` label requires care. It distinguishes the version before out-of-vocabulary words are replaced with `<unk>`; it does **not** mean the text is identical to naturally spaced Wikipedia prose. The corpus retains Moses-style artifacts such as `@-@`, `@,@`, and `@.@`, as well as spaces around punctuation.
#
# A byte-level BPE tokenizer can represent these strings perfectly, but it can also learn and reproduce them. Therefore, normalization must be decided **before** tokenizer training and before defining the exact 20M-token corpus. This chunk gathers evidence from `train` and `validation` only.

# %% [markdown]
# ## 5. Audit blank rows, headings, and tokenization artifacts
#
# The scan is batched so it does not materialize the entire 1.8-million-row training text column as one Python list. Counts are exact for the two development-visible splits. Test remains excluded.

# %%
from collections import Counter, deque
import re

AUDIT_SPLITS = ("train", "validation")
AUDIT_BATCH_SIZE = 10_000
ARTIFACT_MARKERS = {
    "hyphen_placeholder": "@-@",
    "comma_placeholder": "@,@",
    "period_placeholder": "@.@",
}
HEADING_PATTERN = re.compile(r"^\s*=+\s.*?\s=+\s*$")
PUNCTUATION_SPACING_PATTERN = re.compile(r"\s+[,.;:!?%](?=\s|$)")

def audit_text_split(split):
    counts = Counter()
    for batch in split.iter(batch_size=AUDIT_BATCH_SIZE):
        for text in batch["text"]:
            counts["rows"] += 1
            if text is None:
                counts["null_rows"] += 1
                continue

            counts["characters"] += len(text)
            stripped = text.strip()
            if not stripped:
                counts["blank_rows"] += 1
                continue

            counts["nonblank_rows"] += 1
            if HEADING_PATTERN.fullmatch(text):
                counts["heading_rows"] += 1
            else:
                counts["content_rows"] += 1

            for label, marker in ARTIFACT_MARKERS.items():
                counts[label] += text.count(marker)
            counts["punctuation_spacing"] += len(
                PUNCTUATION_SPACING_PATTERN.findall(text)
            )
    return dict(counts)

text_audit = pd.DataFrame(
    {name: audit_text_split(raw_dataset[name]) for name in AUDIT_SPLITS}
).T.fillna(0).astype("int64")

assert tuple(text_audit.index) == AUDIT_SPLITS
assert (text_audit["rows"] == [EXPECTED_ROWS[s] for s in AUDIT_SPLITS]).all()
text_audit
# Out:
#                rows  characters  blank_rows  nonblank_rows  heading_rows  \
# train       1801350   538294333      636321        1165029        305074
# validation     3760     1142150        1299           2461           620
#
#             hyphen_placeholder  comma_placeholder  period_placeholder  \
# train                   881576             149068              158057
# validation                1864                391                 263
#
#             punctuation_spacing  content_rows
# train                   9037068        859955
# validation                18617          1841

# %%
artifact_columns = [*ARTIFACT_MARKERS.keys(), "punctuation_spacing"]
artifact_audit = text_audit[artifact_columns].copy()
for column in artifact_columns:
    artifact_audit[f"{column}_per_1k_nonblank_rows"] = (
        1_000 * artifact_audit[column] / text_audit["nonblank_rows"]
    )

artifact_audit.T
# Out:
#                                                  train    validation
# hyphen_placeholder                        8.815760e+05   1864.000000
# comma_placeholder                         1.490680e+05    391.000000
# period_placeholder                        1.580570e+05    263.000000
# punctuation_spacing                       9.037068e+06  18617.000000
# hyphen_placeholder_per_1k_nonblank_rows   7.566988e+02    757.415685
# comma_placeholder_per_1k_nonblank_rows    1.279522e+02    158.878505
# period_placeholder_per_1k_nonblank_rows   1.356679e+02    106.867127
# punctuation_spacing_per_1k_nonblank_rows  7.756947e+03   7564.811052

# %% [markdown]
# ### How to interpret the audit
#
# - Blank rows and heading rows carry structural information that may help reconstruct article boundaries; they should not be discarded casually.
# - Placeholder counts measure explicit WikiText artifacts.
# - `punctuation_spacing` is a broader diagnostic for Moses-style spacing, not a claim that every match is an error.
# - These are **row and character statistics**, not tokenizer-produced token counts.

# %% [markdown]
# ## 6. Collect deterministic examples from training data
#
# We collect the first few matching training records for diagnosis. This is deterministic and does not consume random state. The validation split is available for aggregate auditing, but examples are taken from training data only.

# %%
def collect_artifact_examples(split, examples_per_marker=3, max_chars=360):
    examples = []
    collected = Counter()
    for row_index, row in enumerate(split):
        text = row["text"] or ""
        for label, marker in ARTIFACT_MARKERS.items():
            if marker in text and collected[label] < examples_per_marker:
                examples.append(
                    {
                        "artifact": label,
                        "row_index": row_index,
                        "raw_text": text.strip()[:max_chars],
                    }
                )
                collected[label] += 1
        if all(collected[label] >= examples_per_marker for label in ARTIFACT_MARKERS):
            break
    return pd.DataFrame(examples)

artifact_examples = collect_artifact_examples(raw_dataset["train"])
artifact_examples
# Out:
#              artifact  row_index  \
# 0  hyphen_placeholder          3
# 1  hyphen_placeholder          9
# 2  hyphen_placeholder         10
# 3   comma_placeholder         35
# 4   comma_placeholder         58
# 5  period_placeholder         58
# 6   comma_placeholder         65
# 7  period_placeholder        186
# 8  period_placeholder        289
#
#                                             raw_text
# 0  Senjō no Valkyria 3 : Unrecorded Chronicles ( ...
# 1  As with previous Valkyira Chronicles games , V...
# 2  The game 's battle system , the BliTZ system ,...
# 3  On its day of release in Japan , Valkyria Chro...
# 4  The arsenal was constructed at the request of ...
# 5  The arsenal was constructed at the request of ...
# 6  The item was intended simply as a piece of new...
# 7  Barker was a devout Christian , and produced r...
# 8  The plain maskray or brown stingray ( Neotrygo...

# %% [markdown]
# ## 7. Define one explicit normalization function
#
# The project uses one short, inspectable sequence of regex rules rather than different ad hoc cleaning for each split. The identical `normalize_wikitext_text` function is applied to training and validation now and will be applied mechanically to test only at final evaluation. This keeps validation perplexity on the same transformed distribution as training.
#
# The function restores WikiText placeholders, repairs common punctuation/bracket spacing, joins common English apostrophe suffixes with Unicode-aware matching, pairs spaced double quotation marks within each row, repairs currency, clock-time, and numeric en-dash spacing, collapses horizontal whitespace, and trims row boundaries. Generic heading rows are handled structurally: only the inner title is normalized, then the equals-sign framing is reconstructed at the original level. It does not lowercase, remove Unicode, rewrite words, or join rows. Spaced single quotation marks and bare plural possessives remain documented residue because the same surface form is contextually ambiguous (for example, `Nameless ' unit` versus `players ' hopes`); a context-free regex cannot safely distinguish them. This policy remains provisional until the revised heading and boundary diagnostics pass on the full development-visible data.

# %%
NORMALIZATION_RULES = (
    (re.compile(r"\s*@-@\s*"), "-"),
    (re.compile(r"\s*@,@\s*"), ","),
    (re.compile(r"\s*@\.@\s*"), "."),
    (re.compile(r"\b(\w+)\s+'\s*(t|s|re|ve|ll|d|m)\b", re.IGNORECASE), r"\1'\2"),
    (re.compile(r"([$£€])\s+(?=\d)"), r"\1"),
    (re.compile(r"\b(\d{1,2})\s*:\s*(\d{2})\b"), r"\1:\2"),
    (re.compile(r"(\d)\s+–\s+(\d)"), r"\1–\2"),
    (re.compile(r"\s+([,.;:!?%])"), r"\1"),
    (re.compile(r"([(\[\{])\s+"), r"\1"),
    (re.compile(r"\s+([)\]\}])"), r"\1"),
    (re.compile(r"[ \t]+"), " "),
)

def tighten_spaced_double_quote_pairs(text):
    quote = '"'
    escaped_quote = re.escape(quote)
    paired_pattern = re.compile(
        rf"{escaped_quote}\s+(.+?)\s+{escaped_quote}"
    )
    return paired_pattern.sub(
        lambda match: f"{quote}{match.group(1).strip()}{quote}", text
    )

HEADING_FRAME_PATTERN = re.compile(
    r"^\s*(?P<left>=+(?:\s+=+)*)\s+"
    r"(?P<title>.*?)"
    r"\s+(?P<right>=+(?:\s+=+)*)\s*$"
)

def parse_heading_row(text):
    match = HEADING_FRAME_PATTERN.fullmatch(text)
    if match is None:
        return None
    left_level = match.group("left").count("=")
    right_level = match.group("right").count("=")
    title = match.group("title").strip()
    if left_level != right_level or not title:
        return None
    return {"level": left_level, "title": title}

def normalize_wikitext_fragment(text):
    normalized = text
    for pattern, replacement in NORMALIZATION_RULES:
        normalized = pattern.sub(replacement, normalized)
    normalized = tighten_spaced_double_quote_pairs(normalized)
    return normalized.strip()

def normalize_wikitext_text(text):
    if not isinstance(text, str):
        raise TypeError(f"Expected str, received {type(text).__name__}")
    heading = parse_heading_row(text)
    if heading is None:
        return normalize_wikitext_fragment(text)
    marker = " ".join("=" for _ in range(heading["level"]))
    title = normalize_wikitext_fragment(heading["title"])
    return f"{marker} {title} {marker}"

# %%
NORMALIZATION_TEST_CASES = {
    "well @-@ known": "well-known",
    "3 @.@ 5 million": "3.5 million",
    "1 @,@ 000 people": "1,000 people",
    "( 1987 )": "(1987)",
    "don 't": "don't",
    "café 's tables": "café's tables",
    "the players ' hopes": "the players ' hopes",
    "$ 3 @.@ 5 million": "$3.5 million",
    "The meeting ran from 12 : 30 to 13 : 05 .": (
        "The meeting ran from 12:30 to 13:05."
    ),
    'the " Nameless ", a penal unit': 'the "Nameless", a penal unit',
    "the ' Nameless ' unit": "the ' Nameless ' unit",
    "the players ' hopes and coaches ' plans": (
        "the players ' hopes and coaches ' plans"
    ),
    "U.S.": "U.S.",
    "2011 – 12 season": "2011–12 season",
    "= ... Thirteen Years Later =": "= ... Thirteen Years Later =",
    "= ? ( film ) =": "= ? (film) =",
    "= = Internal Section = =": "= = Internal Section = =",
}

normalization_test_results = []
for raw_text, expected_text in NORMALIZATION_TEST_CASES.items():
    actual_text = normalize_wikitext_text(raw_text)
    normalization_test_results.append(
        {
            "input": raw_text,
            "expected": expected_text,
            "actual": actual_text,
            "passed": actual_text == expected_text,
        }
    )

normalization_tests = pd.DataFrame(normalization_test_results)
assert normalization_tests["passed"].all(), normalization_tests
normalization_tests
# Out:
#                                         input  \
# 0                              well @-@ known
# 1                             3 @.@ 5 million
# 2                            1 @,@ 000 people
# 3                                    ( 1987 )
# 4                                      don 't
# 5                              café 's tables
# 6                         the players ' hopes
# 7                           $ 3 @.@ 5 million
# 8   The meeting ran from 12 : 30 to 13 : 05 .
# 9              the " Nameless ", a penal unit
# 10                      the ' Nameless ' unit
# 11    the players ' hopes and coaches ' plans
# 12                                       U.S.
# 13                           2011 – 12 season
# 14               = ... Thirteen Years Later =
# 15                             = ? ( film ) =
# 16                   = = Internal Section = =
#
#                                    expected  \
# 0                                well-known
# 1                               3.5 million
# 2                              1,000 people
# 3                                    (1987)
# 4                                     don't
# 5                             café's tables
# 6                       the players ' hopes
# 7                              $3.5 million
# 8      The meeting ran from 12:30 to 13:05.
# 9              the "Nameless", a penal unit
# 10                    the ' Nameless ' unit
# 11  the players ' hopes and coaches ' plans
# 12                                     U.S.
# 13                           2011–12 season
# 14             = ... Thirteen Years Later =
# 15                             = ? (film) =
# 16                 = = Internal Section = =
#
#                                      actual  passed
# 0                                well-known    True
# 1                               3.5 million    True
# 2                              1,000 people    True
# 3                                    (1987)    True
# 4                                     don't    True
# 5                             café's tables    True
# 6                       the players ' hopes    True
# 7                              $3.5 million    True
# 8      The meeting ran from 12:30 to 13:05.    True
# 9              the "Nameless", a penal unit    True
# 10                    the ' Nameless ' unit    True
# 11  the players ' hopes and coaches ' plans    True
# 12                                     U.S.    True
# 13                           2011–12 season    True
# 14             = ... Thirteen Years Later =    True
# 15                             = ? (film) =    True
# 16                 = = Internal Section = =    True

# %%
normalization_comparison = artifact_examples.copy()
normalization_comparison["normalized_text"] = (
    normalization_comparison["raw_text"].map(normalize_wikitext_text)
)
normalization_comparison[["artifact", "row_index", "raw_text", "normalized_text"]]
# Out:
#              artifact  row_index  \
# 0  hyphen_placeholder          3
# 1  hyphen_placeholder          9
# 2  hyphen_placeholder         10
# 3   comma_placeholder         35
# 4   comma_placeholder         58
# 5  period_placeholder         58
# 6   comma_placeholder         65
# 7  period_placeholder        186
# 8  period_placeholder        289
#
#                                             raw_text  \
# 0  Senjō no Valkyria 3 : Unrecorded Chronicles ( ...
# 1  As with previous Valkyira Chronicles games , V...
# 2  The game 's battle system , the BliTZ system ,...
# 3  On its day of release in Japan , Valkyria Chro...
# 4  The arsenal was constructed at the request of ...
# 5  The arsenal was constructed at the request of ...
# 6  The item was intended simply as a piece of new...
# 7  Barker was a devout Christian , and produced r...
# 8  The plain maskray or brown stingray ( Neotrygo...
#
#                                      normalized_text
# 0  Senjō no Valkyria 3: Unrecorded Chronicles (Ja...
# 1  As with previous Valkyira Chronicles games, Va...
# 2  The game's battle system, the BliTZ system, is...
# 3  On its day of release in Japan, Valkyria Chron...
# 4  The arsenal was constructed at the request of ...
# 5  The arsenal was constructed at the request of ...
# 6  The item was intended simply as a piece of new...
# 7  Barker was a devout Christian, and produced re...
# 8  The plain maskray or brown stingray (Neotrygon...

# %% [markdown]
# ## 8. Apply the same function to development-visible splits
#
# Only `train` and `validation` are transformed during development. The test split remains untouched. At final evaluation, the already-frozen `normalize_wikitext_text` function—not a revised copy—will be applied to test.

# %%
def normalize_text_batch(batch):
    return {
        "text": [normalize_wikitext_text(text) for text in batch["text"]]
    }

normalized_development = {
    split_name: raw_dataset[split_name].map(
        normalize_text_batch,
        batched=True,
        batch_size=1_000,
        desc=f"Normalize {split_name}",
    )
    for split_name in AUDIT_SPLITS
}

assert set(normalized_development) == {"train", "validation"}
normalized_development
# Out:
# Normalize train:   0%|          | 0/1801350 [00:00<?, ? examples/s]
# Normalize validation:   0%|          | 0/3760 [00:00<?, ? examples/s]
# {'train': Dataset({
#      features: ['text'],
#      num_rows: 1801350
#  }),
#  'validation': Dataset({
#      features: ['text'],
#      num_rows: 3760
#  })}

# %% [markdown]
# ## 9. Reconstruct article units from level-1 headings
#
# WikiText marks each article with a level-1 heading row such as `= Title =`, padded by a blank row before and after. A level-2 section heading such as `= = History = =` must remain inside its article. Boundaries are detected from raw rows before normalization and require both blank neighbors; normalized rows supply the stored article text.
#
# The reconstructed article ID records the split, article sequence, and source start row. Together with the dataset fingerprint and seed, this gives the later 20M-token sample a reproducible identity.

# %%
def iter_text_rows(split, batch_size=10_000):
    for batch in split.iter(batch_size=batch_size):
        yield from batch["text"]

def iter_with_neighbors(rows):
    iterator = iter(rows)
    previous = None
    current = next(iterator, None)
    following = next(iterator, None)
    row_index = 0
    while current is not None:
        yield row_index, previous, current, following
        previous = current
        current = following
        following = next(iterator, None)
        row_index += 1

def is_blank_row(text):
    return text is not None and not text.strip()

def is_raw_article_start(previous_raw, raw_text, following_raw):
    heading = parse_heading_row(raw_text)
    return (
        heading is not None
        and heading["level"] == 1
        and is_blank_row(previous_raw)
        and is_blank_row(following_raw)
    )

def reconstruct_articles(raw_text_rows, normalized_text_rows, split_name):
    articles = []
    current = None
    last_row_index = -1
    paired_rows = zip(raw_text_rows, normalized_text_rows, strict=True)
    for row_index, previous, row_pair, following in iter_with_neighbors(paired_rows):
        last_row_index = row_index
        raw_text, normalized_text = row_pair
        previous_raw = previous[0] if previous is not None else None
        following_raw = following[0] if following is not None else None
        if is_raw_article_start(previous_raw, raw_text, following_raw):
            if current is not None:
                current["end_row"] = row_index - 1
                current["text"] = "\n".join(current.pop("rows"))
                articles.append(current)

            raw_heading = parse_heading_row(raw_text)
            article_index = len(articles)
            current = {
                "article_id": (
                    f"{split_name}:article-{article_index:05d}:row-{row_index}"
                ),
                "title": normalize_wikitext_fragment(raw_heading["title"]),
                "start_row": row_index,
                "rows": [normalized_text],
            }
        elif current is None:
            if raw_text.strip():
                raise ValueError(
                    f"Nonblank row {row_index} appears before the first article heading."
                )
        else:
            current["rows"].append(normalized_text)

    if current is not None:
        current["end_row"] = last_row_index
        current["text"] = "\n".join(current.pop("rows"))
        articles.append(current)

    return articles

synthetic_raw_rows = [
    "",
    "= First Article =",
    "",
    "Opening text .",
    "",
    "= = Internal Section = =",
    "",
    "More text .",
    "",
    "= ? Second Article =",
    "",
    "Final text .",
]
synthetic_normalized_rows = [
    normalize_wikitext_text(text) for text in synthetic_raw_rows
]
synthetic_articles = reconstruct_articles(
    synthetic_raw_rows, synthetic_normalized_rows, "synthetic"
)
assert len(synthetic_articles) == 2
assert synthetic_articles[0]["title"] == "First Article"
assert "= = Internal Section = =" in synthetic_articles[0]["text"]
assert synthetic_articles[1]["title"] == "? Second Article"
assert synthetic_articles[1]["start_row"] == 9
pd.DataFrame(synthetic_articles).drop(columns="text")
# Out:
#                       article_id             title  start_row  end_row
# 0  synthetic:article-00000:row-1     First Article          1        8
# 1  synthetic:article-00001:row-9  ? Second Article          9       11

# %%
articles_by_split = {
    split_name: reconstruct_articles(
        iter_text_rows(raw_dataset[split_name]),
        iter_text_rows(normalized_development[split_name]),
        split_name,
    )
    for split_name in AUDIT_SPLITS
}

article_audit = pd.DataFrame(
    [
        {
            "split": split_name,
            "articles": len(articles),
            "characters": sum(len(article["text"]) for article in articles),
            "first_article_id": articles[0]["article_id"],
            "last_article_id": articles[-1]["article_id"],
        }
        for split_name, articles in articles_by_split.items()
    ]
).set_index("split")
assert article_audit["articles"].to_dict() == EXPECTED_ARTICLE_COUNTS, (
    "Pinned WikiText article counts changed:\n"
    f"{article_audit['articles'].to_dict()}"
)
article_audit
# Out:
#             articles  characters                first_article_id  \
# split
# train          28472   519078250       train:article-00000:row-1
# validation        60     1102768  validation:article-00000:row-1
#
#                               last_article_id
# split
# train         train:article-28471:row-1801326
# validation  validation:article-00059:row-3714

# %% [markdown]
# ## 10. Diagnose article-boundary counts
#
# The audit resolved three apparent discrepancies. Shape-only matching produced 969 false training boundaries from internal table and equation rows. Ordinary prose normalization destroyed the framing of 11 punctuation-leading training titles and one validation title. Finally, the original WikiText summary reports 28,475 training articles, while the pinned released corpus reproducibly contains 28,472 blank-padded training documents; independent downstream work also reports 28,472.
#
# The structural rule therefore remains deliberately strict: detect boundaries on raw text, require blank rows immediately before and after a level-1 heading, then normalize the stored text and heading interior. The 28,472 training and 60 validation counts are hard assertions tied to the pinned Hub revision. The diagnostic cells below preserve the evidence that relaxing blank padding would reintroduce references and table fragments. No test text is inspected.

# %%
def compare_heading_detection(raw_split, normalized_split):
    raw_shape_count = 0
    raw_blank_padded_count = 0
    changed_rows = []
    paired_rows = zip(
        iter_text_rows(raw_split),
        iter_text_rows(normalized_split),
        strict=True,
    )
    for row_index, previous, row_pair, following in iter_with_neighbors(paired_rows):
        raw_text, normalized_text = row_pair
        previous_raw = previous[0] if previous is not None else None
        following_raw = following[0] if following is not None else None
        raw_heading = parse_heading_row(raw_text)
        normalized_heading = parse_heading_row(normalized_text)
        raw_level = raw_heading["level"] if raw_heading is not None else None
        normalized_level = (
            normalized_heading["level"]
            if normalized_heading is not None else None
        )
        raw_shape_count += raw_level == 1
        raw_blank_padded_count += is_raw_article_start(
            previous_raw, raw_text, following_raw
        )
        if raw_level != normalized_level:
            changed_rows.append(
                {
                    "row_index": row_index,
                    "raw_level": raw_level,
                    "normalized_level": normalized_level,
                    "raw_text": raw_text,
                    "normalized_text": normalized_text,
                }
            )
    return raw_shape_count, raw_blank_padded_count, changed_rows

heading_diagnostic_rows = []
heading_classification_changes = {}
for split_name in AUDIT_SPLITS:
    raw_shape_count, raw_blank_padded_count, changed_rows = (
        compare_heading_detection(
        raw_dataset[split_name], normalized_development[split_name]
        )
    )
    heading_classification_changes[split_name] = changed_rows
    reconstructed_count = len(articles_by_split[split_name])
    expected_count = EXPECTED_ARTICLE_COUNTS[split_name]
    heading_diagnostic_rows.append(
        {
            "split": split_name,
            "published_articles": expected_count,
            "raw_shape_candidates": raw_shape_count,
            "raw_blank_padded": raw_blank_padded_count,
            "reconstructed_units": reconstructed_count,
            "unit_delta": reconstructed_count - expected_count,
            "classification_changes": len(changed_rows),
        }
    )

heading_diagnostics = pd.DataFrame(heading_diagnostic_rows).set_index("split")
heading_diagnostics
# Out:
#             published_articles  raw_shape_candidates  raw_blank_padded  \
# split
# train                    28472                 29444             28472
# validation                  60                    60                60
#
#             reconstructed_units  unit_delta  classification_changes
# split
# train                     28472           0                       0
# validation                   60           0                       0

# %%
changed_heading_rows = pd.DataFrame(
    [
        {"split": split_name, **row}
        for split_name, rows in heading_classification_changes.items()
        for row in rows
    ]
)
changed_heading_rows
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def iter_centered_windows(rows, radius=3):
    if radius < 1:
        raise ValueError("radius must be at least 1")
    buffer = deque([(None, None)] * radius, maxlen=2 * radius + 1)
    for item in enumerate(rows):
        buffer.append(item)
        if len(buffer) == buffer.maxlen:
            yield list(buffer)
    for _ in range(radius):
        buffer.append((None, None))
        if len(buffer) == buffer.maxlen:
            yield list(buffer)

def unpadded_level1_candidates(raw_split, radius=3, display_chars=140):
    hits = []
    for window in iter_centered_windows(iter_text_rows(raw_split), radius):
        center_index, center_text = window[radius]
        if center_index is None:
            continue
        heading = parse_heading_row(center_text)
        if heading is None or heading["level"] != 1:
            continue

        previous_text = window[radius - 1][1]
        following_text = window[radius + 1][1]
        if is_raw_article_start(previous_text, center_text, following_text):
            continue

        following_rows = [text for _, text in window[radius + 1:]]
        next_nonblank = next(
            (text for text in following_rows if text is not None and text.strip()),
            None,
        )
        next_heading = (
            parse_heading_row(next_nonblank) if next_nonblank is not None else None
        )
        next_nonblank_is_prose = (
            next_nonblank is not None
            and next_heading is None
            and (len(next_nonblank.strip()) > 150 or len(next_nonblank.split()) >= 20)
        )
        nearby_level2 = any(
            parsed is not None and parsed["level"] == 2
            for parsed in (
                parse_heading_row(text)
                for text in following_rows
                if text is not None
            )
        )
        previous_blank = is_blank_row(previous_text)
        following_blank = is_blank_row(following_text)
        one_sided_blank = previous_blank != following_blank
        heuristic_hit = one_sided_blank and (next_nonblank_is_prose or nearby_level2)
        context = "\n".join(
            f"{row_index}: {(text or '').strip()[:display_chars]}"
            for row_index, text in window
            if row_index is not None
        )
        hits.append(
            {
                "row_index": center_index,
                "title": heading["title"],
                "previous_blank": previous_blank,
                "following_blank": following_blank,
                "one_sided_blank": one_sided_blank,
                "next_nonblank_chars": (
                    len(next_nonblank.strip()) if next_nonblank is not None else None
                ),
                "next_nonblank_level": (
                    next_heading["level"] if next_heading is not None else None
                ),
                "next_nonblank_is_prose": next_nonblank_is_prose,
                "nearby_level2": nearby_level2,
                "heuristic_hit": heuristic_hit,
                "context": context,
            }
        )
    return pd.DataFrame(hits)

unpadded_train_candidates = unpadded_level1_candidates(raw_dataset["train"])
candidate_context_summary = (
    unpadded_train_candidates.groupby(
        ["previous_blank", "following_blank"], dropna=False
    )
    .agg(candidates=("row_index", "size"), heuristic_hits=("heuristic_hit", "sum"))
    .reset_index()
)
candidate_context_summary
# Out:
#    previous_blank  following_blank  candidates  heuristic_hits
# 0           False            False         967               0
# 1            True            False           5               1

# %%
one_sided_candidates = unpadded_train_candidates.query("one_sided_blank").copy()
ONE_SIDED_DISPOSITIONS = {
    8_030: "bibliography entry",
    59_100: "naval table fragment",
    462_205: "bibliography reference number",
    525_863: "bibliography volume metadata",
    1_161_374: "naval table fragment",
}
assert set(one_sided_candidates["row_index"]) == set(ONE_SIDED_DISPOSITIONS), (
    "Pinned one-sided boundary exceptions changed."
)
one_sided_candidates["audit_disposition"] = one_sided_candidates["row_index"].map(
    ONE_SIDED_DISPOSITIONS
)
print(
    "unpadded candidates:", len(unpadded_train_candidates),
    "| no blank neighbors:", (~unpadded_train_candidates["one_sided_blank"]).sum(),
    "| one blank neighbor:", len(one_sided_candidates),
)
display_columns = [
    "row_index",
    "title",
    "previous_blank",
    "following_blank",
    "next_nonblank_chars",
    "next_nonblank_level",
    "next_nonblank_is_prose",
    "nearby_level2",
    "audit_disposition",
    "context",
]
with pd.option_context("display.max_colwidth", 1_000, "display.max_rows", 100):
    display(one_sided_candidates[display_columns])
# Out:
# unpadded candidates: 972 | no blank neighbors: 967 | one blank neighbor: 5
#      row_index  \
# 7         8030
# 85       59100
# 420     462205
# 444     525863
# 700    1161374
#
#                                                                                 title  \
# 7    De dezas a espwa : interviews with persons affected by the 2010 Haiti earthquake
# 85                                                               British Royal Navy ,
# 420                                                                           56 ; FN
# 444                                                                 Volume 6 , Part 2
# 700                                                              British Royal Navy ,
#
#      previous_blank  following_blank  next_nonblank_chars next_nonblank_level  \
# 7              True            False                   99                None
# 85             True            False                   46                None
# 420            True            False                  120                None
# 444            True            False                    9                None
# 700            True            False                   13                None
#
#      next_nonblank_is_prose  nearby_level2              audit_disposition  \
# 7                     False          False             bibliography entry
# 85                    False          False           naval table fragment
# 420                    True          False  bibliography reference number
# 444                   False          False   bibliography volume metadata
# 700                   False          False           naval table fragment
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          context
# 7                                                                                                                                                                                                                                                                                               8027: \n8028: The Haiti 2010 earthquake has been depicted in the novel God Loves Haiti , by Dimitry Elias Léger .\n8029: \n8030: = De dezas a espwa : interviews with persons affected by the 2010 Haiti earthquake =\n8031: yon koze ak moun tranblemandetè ann Ayiti a afekte . United States : Xlibris . ISBN 9781479709472 .\n8032: \n8033:
# 85                                                                                                                                                                                                                                                                                                                     59097: A † symbol indicates that the officer was killed during the action or subsequently died of wounds received .\n59098: The ships are ordered in the sequence in which they formed up for battle .\n59099: \n59100: = British Royal Navy , =\n59101: French Navy , = Navy of the Kingdom of Italy .\n59102: \n59103:
# 420  462202: \n462203: The species is not known to be threatened and its conservation status is classified as least concern by the IUCN . It is a widely distribute\n462204: \n462205: = 56 ; FN =\n462206: 54 @-@ 55 ( Rodentia , Sigmodontinae ) ( subscription required ) . Genetics and Molecular Biology 36 ( 2 ) : 201 – 206 .\n462207: Musser , G.G. and Carleton , M.D. 2005 . Superfamily Muroidea . Pp . 894 – 1531 in Wilson , D.E. and Reeder , D.M. ( eds . ) . Mammal Specie\n462208: Pardiñas , U.F.J. 1995 . Novedosos cricetidos ( Mammalia , Rodentia ) en el Holoceno de la Región Pampeana , Argentina . Ameghiniana 32 ( 2
# 444                                                                                                                                                                                                                    525860: 2009 – A street in Wieliczka was named in his honour\n525861: 2011 – An interactive Google logo inspired by The Cyberiad was created and published in his honor for the 60th anniversary of his first publ\n525862: \n525863: = Volume 6 , Part 2 =\n525864: July 1979\n525865: Stanislaw Lem , Jeet Heer , Boston Globe Ideas , 15 December 2004\n525866: The writing of Stanislaw Lem – Reviews by Matt McIrvin
# 700                                                                                                                                                                                                                                                                                                                                       1161371: A † symbol indicates that the officer was killed during the action or subsequently died of wounds received .\n1161372: The ships are ordered in the sequence in which they formed up for battle .\n1161373: \n1161374: = British Royal Navy , =\n1161375: French Navy .\n1161376: \n1161377:

# %%
validation_titles = pd.DataFrame(
    [
        {
            "unit_index": index,
            "title": article["title"],
            "start_row": article["start_row"],
            "end_row": article["end_row"],
            "rows": article["end_row"] - article["start_row"] + 1,
        }
        for index, article in enumerate(articles_by_split["validation"])
    ]
)
with pd.option_context("display.max_rows", None):
    display(validation_titles)
# Out:
#     unit_index                                              title  start_row  \
# 0            0                                   Homarus gammarus          1
# 1            1                                      Frank Headlam         47
# 2            2                            M-82 (Michigan highway)         78
# 3            3                                     Shikamaru Nara        103
# 4            4                              Meridian, Mississippi        132
# 5            5                                         Papa Stour        346
# 6            6                       Angel of Death (Slayer song)        429
# 7            7                                     Calvin McCarty        470
# 8            8                           Hurricane Beatriz (2011)        554
# 9            9                                The Bourgeois Blues        571
# 10          10                               Sorry (Madonna song)        602
# 11          11                              High Five Interchange        662
# 12          12                                       Tim Richmond        695
# 13          13                              Trout Creek Mountains        759
# 14          14                                   Mycena inclinata        814
# 15          15                                       Capel Lligwy        850
# 16          16  2011–12 Michigan Wolverines men's basketball team        873
# 17          17                               Upsilon Andromedae b        955
# 18          18                                   Daniel Radcliffe        979
# 19          19                           ... Thirteen Years Later       1040
# 20          20                                New Jersey Route 29       1065
# 21          21                     First Mongol invasion of Burma       1098
# 22          22                            Battle of Edson's Ridge       1221
# 23          23                                New Jersey Route 50       1299
# 24          24                            Air Rhodesia Flight 825       1321
# 25          25                                              Tikal       1415
# 26          26                    Tropical Storm Josephine (2008)       1606
# 27          27                                       Mount Elbert       1625
# 28          28                             Scientology in Germany       1657
# 29          29                          Japanese battleship Asahi       1757
# 30          30                          Training Day (The Office)       1795
# 31          31                                   J. C. W. Beckham       1826
# 32          32           1888–89 New Zealand Native football team       1877
# 33          33                                       Éva Gauthier       1977
# 34          34                        Battle of Sullivan's Island       2018
# 35          35                                        Hu Zhengyan       2071
# 36          36                              Raid on Manila (1798)       2115
# 37          37                                      B of the Bang       2154
# 38          38                       Battle of the Hongorai River       2188
# 39          39               Sonic the Hedgehog (1991 video game)       2237
# 40          40                                 The Same Old Story       2320
# 41          41                     Randy Blythe manslaughter case       2352
# 42          42                           U.S. Route 2 in Michigan       2450
# 43          43                               Butterfly World Tour       2525
# 44          44                                Thelnetham Windmill       2594
# 45          45                                       Sailor Mouth       2694
# 46          46                      Military history of Australia       2722
# 47          47                                     Ward Churchill       2975
# 48          48                       Exit Through the Kwik-E-Mart       3117
# 49          49                                 The Boat Race 2008       3140
# 50          50                  Fort Scott National Historic Site       3164
# 51          51                               Slammiversary (2008)       3200
# 52          52                                Home Made Mince Pie       3265
# 53          53                                  Back Off Boogaloo       3284
# 54          54                     Where the Streets Have No Name       3347
# 55          55                       Nazarov cyclization reaction       3417
# 56          56                                    Horrible Bosses       3490
# 57          57                 1985 Rajneeshee assassination plot       3582
# 58          58                                    Die Another Day       3636
# 59          59                                        Rakie Ayola       3714
#
#     end_row  rows
# 0        46    46
# 1        77    31
# 2       102    25
# 3       131    29
# 4       345   214
# 5       428    83
# 6       469    41
# 7       553    84
# 8       570    17
# 9       601    31
# 10      661    60
# 11      694    33
# 12      758    64
# 13      813    55
# 14      849    36
# 15      872    23
# 16      954    82
# 17      978    24
# 18     1039    61
# 19     1064    25
# 20     1097    33
# 21     1220   123
# 22     1298    78
# 23     1320    22
# 24     1414    94
# 25     1605   191
# 26     1624    19
# 27     1656    32
# 28     1756   100
# 29     1794    38
# 30     1825    31
# 31     1876    51
# 32     1976   100
# 33     2017    41
# 34     2070    53
# 35     2114    44
# 36     2153    39
# 37     2187    34
# 38     2236    49
# 39     2319    83
# 40     2351    32
# 41     2449    98
# 42     2524    75
# 43     2593    69
# 44     2693   100
# 45     2721    28
# 46     2974   253
# 47     3116   142
# 48     3139    23
# 49     3163    24
# 50     3199    36
# 51     3264    65
# 52     3283    19
# 53     3346    63
# 54     3416    70
# 55     3489    73
# 56     3581    92
# 57     3635    54
# 58     3713    78
# 59     3759    46

# %%
train_articles = articles_by_split["train"]
shortest_train_segments = pd.DataFrame(
    [
        {
            "unit_index": index,
            "rows": article["end_row"] - article["start_row"] + 1,
            "characters": len(article["text"]),
            "title": article["title"],
            "previous_title": (
                train_articles[index - 1]["title"] if index else None
            ),
            "next_title": (
                train_articles[index + 1]["title"]
                if index + 1 < len(train_articles) else None
            ),
            "start_row": article["start_row"],
        }
        for index, article in enumerate(train_articles)
    ]
).sort_values(["rows", "characters", "unit_index"]).head(25)
shortest_train_segments
# Out:
#        unit_index  rows  characters  \
# 14731       14731     6         288
# 15537       15537     6        1764
# 13848       13848     7         443
# 20663       20663     8         387
# 22251       22251    10        5501
# 22400       22400    11        1661
# 2668         2668    11        1900
# 2564         2564    11        2813
# 9382         9382    11        2847
# 8868         8868    11        3351
# 4178         4178    11        4198
# 7206         7206    12         984
# 8859         8859    12        1753
# 18154       18154    12        2666
# 27481       27481    12        3346
# 10817       10817    12        3767
# 21902       21902    12        3975
# 7956         7956    12        4109
# 1118         1118    12        4463
# 26551       26551    12        4641
# 3550         3550    12        5074
# 12676       12676    12        5149
# 24491       24491    12        5184
# 3016         3016    12        5243
# 28327       28327    12        5274
#
#                                                    title  \
# 14731                          History of York City F.C.
# 15537  United States Code Congressional and Administr...
# 13848                                        Rangs Group
# 20663                                    SMS Prinz Eugen
# 22251                    Tornada (Occitan literary term)
# 22400                                        HD 217107 c
# 2668                       Romanus (bishop of Rochester)
# 2564                                           Bregowine
# 9382                                     Bergen Aviation
# 8868                No. 4 Operational Training Unit RAAF
# 4178                       RAAF Transport Flight (Japan)
# 7206                       Baltimore Urban Debate League
# 8859                                     1973 CECAFA Cup
# 18154                                             Goshin
# 27481                                           Cynesige
# 10817                             Eustathios Daphnomeles
# 21902                                            Wighard
# 7956           No. 1 Initial Flying Training School RAAF
# 1118                               Fighter Squadron RAAF
# 26551                                   No. 72 Wing RAAF
# 3550                               No. 391 Squadron RAAF
# 12676       No. 3 Elementary Flying Training School RAAF
# 24491                               Paratheria (mammals)
# 3016                                    No. 76 Wing RAAF
# 28327                                   No. 77 Wing RAAF
#
#                                    previous_title  \
# 14731                                Watford F.C.
# 15537                      Charles Frederick Horn
# 13848  Call of Cthulhu: Dark Corners of the Earth
# 20663                             Dolls and Dolls
# 22251                    Interstate 15 in Arizona
# 22400                     Hurricane Joanne (1972)
# 2668                       Hurricane Emily (1993)
# 2564                      Mississippi Highway 792
# 9382                                      CM Punk
# 8868                     April 2014 lunar eclipse
# 4178                    SM U-15 (Austria-Hungary)
# 7206                    California State Route 55
# 8859                             Clackline Bridge
# 18154                         Underneath the Tree
# 27481                              Jonathan Krohn
# 10817                          Geoffroy's tamarin
# 21902                                 Common tern
# 7956                      Hurricane Gladys (1975)
# 1118                         The Utility of Force
# 26551                    Discipline Global Mobile
# 3550         History of Roman and Byzantine domes
# 12676                   Bill Cosby in advertising
# 24491                    Saskatchewan Highway 641
# 3016                             USAir Flight 405
# 28327                        HMS Empress of India
#
#                                next_title  start_row
# 14731                   SMS Kaiser (1911)     927593
# 15537                My First Kiss (song)     978192
# 13848            New York State Route 275     872638
# 20663                     Nathaniel Dance    1304930
# 22251                      Samuel Johnson    1402936
# 22400                        Hooray Henry    1411497
# 2668               William III of England     166813
# 2564   Homer vs. the Eighteenth Amendment     160433
# 9382             Italian cruiser Euridice     591562
# 8868                      HMS Hermes (95)     558901
# 4178                         John Hancock     261659
# 7206                       Scheiße (song)     452626
# 8859                Release (The X-Files)     558424
# 18154                            Lundomys    1143805
# 27481                   Lowell Mill Girls    1738843
# 10817                Robert Sterling Yard     683972
# 21902                            Calutron    1381389
# 7956                        Lionel Luthor     499715
# 1118                     One Times Square      70086
# 26551                 Utricularia inflata    1679533
# 3550                Turf War (The Office)     222309
# 12676                    Superman in film     799484
# 24491                New Jersey Route 183    1543227
# 3016                         Electric Mud     189087
# 28327                       Panic of 1907    1792426

# %% [markdown]
# ## 11. Locked sampling design for the 20M-token corpus
#
# The 16,384-token byte-level BPE tokenizer will be trained on the **entire normalized official training split**, never on validation or test. The model-training corpus will then be sampled from that same training split. This avoids circularity: the tokenizer must exist before article token counts and the exact 20M-token subset can be computed.
#
# After the tokenizer and document-boundary special token are defined, corpus construction will:
#
# 1. create a fresh local generator with `rng = np.random.default_rng(SEED)`;
# 2. generate one deterministic permutation of training article indices;
# 3. encode each article and append one document-boundary token;
# 4. count that boundary token inside the exact 20,000,000-token budget;
# 5. stop when the running count first crosses 20,000,000 tokens;
# 6. truncate only the final selected article sequence to reach exactly 20,000,000; and
# 7. save a manifest containing the dataset fingerprint, seed, ordered article IDs, full and included per-article token counts, whether each boundary token was included, final-article truncation length, tokenizer checksum, and total token count.
#
# This samples approximately 20% of the available training text without shuffling paragraphs or destroying within-article continuity. Validation and later test retain article boundaries and use the identical normalization function, but they are not part of the 20M-token training sample.
#
# **Pause here.** The data-audit phase is closed: this v8 notebook completed successfully against the pinned dataset revision with all assertions passing. The next reviewable chunk chooses the document-boundary token, trains the 16,384-token byte-level BPE tokenizer on the full normalized pinned training split, validates encode/decode behavior, and records the tokenizer checksum.
